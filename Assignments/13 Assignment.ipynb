# %%
import xml.etree.ElementTree as ET
import urllib.request, urllib.parse, urllib.error

while True:
    address = input('Enter Location: ')
    if len(address) < 1: break
    
    parms = dict()
    parms['address'] = address



fhand = urllib.request.urlopen('https://py4e-data.dr-chuck.net/comments_42.xml')
fhand.decode()
tree = ET.fromstring(fhand)
lst = tree.findall('comments/comment')
print('User count:', len(lst))
for item in lst:
    print('Name: ', item.find('name').text)
    print('Count: ', item.find('count').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\victo\OneDrive\Escritorio\Python\13 Assignment.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/victo/OneDrive/Escritorio/Python/13%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import urllib.request, urllib.parse, urllib.error
#       <a href='vscode-notebook-cell:/c%3A/Users/victo/OneDrive/Escritorio/Python/13%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> fhand = urllib.request.urlopen('https://py4e-data.dr-chuck.net/comments_42.xml')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/victo/OneDrive/Escritorio/Python/13%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> fhand.decode()
#       <a href='vscode-notebook-cell:/c%3A/Users/victo/OneDrive/Escritorio/Python/13%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> tree = ET.fromstring(fhand)
#       <a href='vscode-notebook-cell:/c%3A/Users/victo/OneDrive/Escritorio/Python/13%20Assignment.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> lst = tree.findall('comments/comment')
#
# AttributeError: 'HTTPResponse' object has no attribute 'decode'

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro


ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE


while True:
    address = input('Enter location: ')
    count = 0
    if len(address) < 1: break

    url = address
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)

    data = uh.read()
    print('Retrieved', len(data), 'characters')
    tree = ET.fromstring(data)
    lst = tree.findall('comments/comment')
    for item in lst:
        count = count + int(item.find('count').text)
        print('Name:', item.find('name').text)
        print('Count:', item.find('count').text)
    print(count)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/comments_1918735.xml
# Retrieved 4212 characters
# Name: Oryn
# Count: 100
# Name: Elsie
# Count: 100
# Name: Avinash
# Count: 96
# Name: Kristal
# Count: 92
# Name: Eduardo
# Count: 90
# Name: Piper
# Count: 88
# Name: Anmar
# Count: 87
# Name: Dugald
# Count: 85
# Name: Zahra
# Count: 85
# Name: Leela
# Count: 82
# Name: Morna
# Count: 82
# Name: Jaden
# Count: 80
# Name: Laiyah
# Count: 77
# Name: Abhinav
# Count: 76
# Name: Calder
# Count: 73
# Name: Gian
# Count: 69
# Name: Claire
# Count: 68
# Name: Ander
# Count: 64
# Name: Rona
# Count: 57
# Name: Avsta
# Count: 53
# Name: Kohen
# Count: 50
# Name: Hafsah
# Count: 50
# Name: Kesia
# Count: 47
# Name: Zacharius
# Count: 44
# Name: Harleigh
# Count: 44
# Name: Umer
# Count: 42
# Name: Mathilda
# Count: 39
# Name: Susan
# Count: 36
# Name: Alishah
# Count: 35
# Name: Mati
# Count: 33
# Name: Trassa
# Count: 31
# Name: Yasmin
# Count: 28
# Name: Rowenna
# Count: 26
# Name: Antoine
# Count: 25
# Name: Seaan
# Count: 25
# Name: Amrit
# Count: 24
# Name: Darl
# Count: 22
# Name: Ellisandro
# Count: 22
# Name: Mhia
# Count: 18
# Name: Kasey
# Count: 16
# Name: Catharine
# Count: 15
# Name: Glen
# Count: 15
# Name: Simran
# Count: 14
# Name: Cacie
# Count: 14
# Name: Rupert
# Count: 12
# Name: Amir
# Count: 12
# Name: Emilia
# Count: 6
# Name: Ehsan
# Count: 4
# Name: Kamryn
# Count: 3
# Name: Naina
# Count: 2
# 2358
